# %%
import pandas as pd
df = pd.read_csv("cox-violent-parsed_filt.csv")
df
# Out:
#         id                   name       first        last     sex         dob  \
# 0      1.0       miguel hernandez      miguel   hernandez    Male  18/04/1947
# 1      2.0       miguel hernandez      miguel   hernandez    Male  18/04/1947
# 2      3.0           michael ryan     michael        ryan    Male  06/02/1985
# 3      4.0            kevon dixon       kevon       dixon    Male  22/01/1982
# 4      5.0               ed philo          ed       philo    Male  14/05/1991
# ...    ...                    ...         ...         ...     ...         ...
# 18311  NaN  alexsandra beauchamps  alexsandra  beauchamps  Female  21/12/1984
# 18312  NaN        winston gregory     winston     gregory    Male  01/10/1958
# 18313  NaN            farrah jean      farrah        jean  Female  17/11/1982
# 18314  NaN    florencia sanmartin   florencia   sanmartin  Female  18/12/1992
# 18315  NaN    florencia sanmartin   florencia   sanmartin  Female  18/12/1992
#
# ...

# %%
print(df.columns.tolist())
# Out:
# ['id', 'name', 'first', 'last', 'sex', 'dob', 'age', 'age_cat', 'race', 'juv_fel_count', 'decile_score', 'juv_misd_count', 'juv_other_count', 'priors_count', 'days_b_screening_arrest', 'c_jail_in', 'c_jail_out', 'c_days_from_compas', 'c_charge_degree', 'c_charge_desc', 'is_recid', 'r_charge_degree', 'r_days_from_arrest', 'r_offense_date', 'r_charge_desc', 'r_jail_in', 'violent_recid', 'is_violent_recid', 'vr_charge_degree', 'vr_offense_date', 'vr_charge_desc', 'type_of_assessment', 'decile_score.1', 'score_text', 'screening_date', 'v_type_of_assessment', 'v_decile_score', 'v_score_text', 'priors_count.1', 'event']

# %%
print(df['priors_count'].equals(df['priors_count.1']))
print(df['decile_score'].equals(df['decile_score.1']))
# Out:
# True
# True

# %%
df = df.drop(columns=['priors_count.1'])
df = df.drop(columns=['decile_score.1'])
len(df.columns.tolist())
# Out:
# 38

# %%
df.duplicated(subset=['name', 'dob']).sum()
# Out:
# np.int64(7317)

# %%
df = df.drop_duplicates(subset=['name', 'dob'], keep='first')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10999 entries, 0 to 18314
# Data columns (total 38 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       6601 non-null   float64
#  1   name                     10999 non-null  object
#  2   first                    10999 non-null  object
#  3   last                     10999 non-null  object
#  4   sex                      10999 non-null  object
#  5   dob                      10999 non-null  object
#  6   age                      10999 non-null  int64
#  7   age_cat                  10999 non-null  object
#  8   race                     10999 non-null  object
#  9   juv_fel_count            10999 non-null  int64
#  10  decile_score             10999 non-null  int64
#  11  juv_misd_count           10999 non-null  int64
#  12  juv_other_count          10999 non-null  int64
#  13  priors_count             10999 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# id                          4398
# name                           0
# first                          0
# last                           0
# sex                            0
# dob                            0
# age                            0
# age_cat                        0
# race                           0
# juv_fel_count                  0
# decile_score                   0
# juv_misd_count                 0
# juv_other_count                0
# priors_count                   0
# days_b_screening_arrest     1096
# c_jail_in                   1096
# c_jail_out                  1096
# c_days_from_compas           690
# c_charge_degree              690
# c_charge_desc                697
# is_recid                       0
# r_charge_degree             7526
# r_days_from_arrest          8682
# r_offense_date              7526
# r_charge_desc               7584
# r_jail_in                   8682
# violent_recid              10999
# is_violent_recid               0
# ...

# %%
print(df['type_of_assessment'].value_counts()) # all same value
df.drop(columns=['type_of_assessment'], inplace=True)
# Out:
# type_of_assessment
# Risk of Recidivism    10999
# Name: count, dtype: int64

# %%
df['v_type_of_assessment'].value_counts() # all same value
df.drop(columns=['v_type_of_assessment'], inplace=True)

# %%
df['event'].value_counts()
# Out:
# event
# 0    10479
# 1      520
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                  id           age  juv_fel_count  decile_score  \
# count   6601.000000  10999.000000   10999.000000  10999.000000
# mean    5492.483260     35.112647       0.061096      4.369943
# std     3174.277934     12.027804       0.451195      2.871778
# min        1.000000     18.000000       0.000000     -1.000000
# 25%     2732.000000     25.000000       0.000000      2.000000
# 50%     5510.000000     32.000000       0.000000      4.000000
# 75%     8232.000000     43.000000       0.000000      7.000000
# max    10999.000000     96.000000      20.000000     10.000000
#
#        juv_misd_count  juv_other_count  priors_count  days_b_screening_arrest  \
# count    10999.000000     10999.000000  10999.000000              9903.000000
# mean         0.075461         0.095009      3.080735                -0.654347
# std          0.451037         0.476748      4.676557                73.802301
# min          0.000000         0.000000      0.000000              -597.000000
# ...

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#          id                   name       first        last     sex  \
# 0       1.0       miguel hernandez      miguel   hernandez    Male
# 1       3.0           michael ryan     michael        ryan    Male
# 2       4.0            kevon dixon       kevon       dixon    Male
# 3       5.0               ed philo          ed       philo    Male
# 4      10.0            marcu brown       marcu       brown    Male
# ...     ...                    ...         ...         ...     ...
# 10994   NaN        malcolm simmons     malcolm     simmons    Male
# 10995   NaN  alexsandra beauchamps  alexsandra  beauchamps  Female
# 10996   NaN        winston gregory     winston     gregory    Male
# 10997   NaN            farrah jean      farrah        jean  Female
# 10998   NaN    florencia sanmartin   florencia   sanmartin  Female
#
#               dob  age          age_cat              race  juv_fel_count  ...  \
# 0      18/04/1947   69  Greater than 45             Other              0  ...
# ...

# %%
df['id'] = range(1, len(df) + 1)
df
# Out:
#           id                   name       first        last     sex  \
# 0          1       miguel hernandez      miguel   hernandez    Male
# 1          2           michael ryan     michael        ryan    Male
# 2          3            kevon dixon       kevon       dixon    Male
# 3          4               ed philo          ed       philo    Male
# 4          5            marcu brown       marcu       brown    Male
# ...      ...                    ...         ...         ...     ...
# 10994  10995        malcolm simmons     malcolm     simmons    Male
# 10995  10996  alexsandra beauchamps  alexsandra  beauchamps  Female
# 10996  10997        winston gregory     winston     gregory    Male
# 10997  10998            farrah jean      farrah        jean  Female
# 10998  10999    florencia sanmartin   florencia   sanmartin  Female
#
#               dob  age          age_cat              race  juv_fel_count  ...  \
# ...

# %%
df.drop(columns=['id', 'name', 'first', 'last', 'dob', 'vr_charge_desc', 'r_charge_desc' ], inplace=True)
df
# Out:
#           sex  age          age_cat              race  juv_fel_count  \
# 0        Male   69  Greater than 45             Other              0
# 1        Male   31          25 - 45         Caucasian              0
# 2        Male   34          25 - 45  African-American              0
# 3        Male   24     Less than 25  African-American              0
# 4        Male   23     Less than 25  African-American              0
# ...       ...  ...              ...               ...            ...
# 10994    Male   23     Less than 25  African-American              0
# 10995  Female   31          25 - 45  African-American              0
# 10996    Male   57  Greater than 45             Other              0
# 10997  Female   33          25 - 45  African-American              0
# 10998  Female   23     Less than 25          Hispanic              0
#
#        decile_score  juv_misd_count  juv_other_count  priors_count  \
# 0                 1               0                0             0
# ...

# %%
df.columns
df.to_csv('cox-violent-parsed_filt_processed.csv', index=False)

# %%
df = pd.read_csv("cox-violent-parsed_filt_processed.csv")
df
# Out:
#           sex  age          age_cat              race  juv_fel_count  \
# 0        Male   69  Greater than 45             Other              0
# 1        Male   31          25 - 45         Caucasian              0
# 2        Male   34          25 - 45  African-American              0
# 3        Male   24     Less than 25  African-American              0
# 4        Male   23     Less than 25  African-American              0
# ...       ...  ...              ...               ...            ...
# 10994    Male   23     Less than 25  African-American              0
# 10995  Female   31          25 - 45  African-American              0
# 10996    Male   57  Greater than 45             Other              0
# 10997  Female   33          25 - 45  African-American              0
# 10998  Female   23     Less than 25          Hispanic              0
#
#        decile_score  juv_misd_count  juv_other_count  priors_count  \
# 0                 1               0                0             0
# ...
